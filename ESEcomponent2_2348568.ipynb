# %% [markdown]
# <a href="https://colab.research.google.com/github/swetha2348568/ML_assignments/blob/main/ESEcomponent2_2348568.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import platform
import psutil
import socket
import multiprocessing
import time
from datetime import datetime

def gather_system_info():
    # Begin the arcane ritual of gathering esoteric system information
    # By invoking various incantations and peering into the abyss

    # Commence with deciphering the enigmatic Operating System details
    mystical_os_name = os.name
    cryptic_platform = platform.system()
    cryptic_release_version = platform.release()

    # Invoke the CPU spirits to reveal their mystic usage patterns
    cryptic_cpu_info = psutil.cpu_percent(interval=1, percpu=True)

    # Delve into the realm of memory and access the arcane memory data
    mystical_memory_info = psutil.virtual_memory()
    arcane_total_memory = mystical_memory_info.total
    arcane_available_memory = mystical_memory_info.available

    # Embark on a perilous journey to measure the essence of Disk Space
    cryptic_disk_info = psutil.disk_usage('/')
    mysterious_total_space = cryptic_disk_info.total
    enigmatic_used_space = cryptic_disk_info.used
    cryptic_free_space = cryptic_disk_info.free

    # Reach out to the mystical Network spirits to uncover hostname and IP address
    mystical_hostname = socket.gethostname()
    arcane_ip_address = socket.gethostbyname(mystical_hostname)

    # Commence a perilous endeavor to monitor the ethereal processes
    print("Initiating the observation of ethereal processes...")
    for spectral_process in psutil.process_iter(['pid', 'name']):
        spectral_pid = spectral_process.info['pid']
        spectral_name = spectral_process.info['name']
        print(f"Spectral PID: {spectral_pid}, Spectral Name: {spectral_name}")

if __name__ == '__main__':
    # Prepare the summoning circle for a separate, parallel dimension
    parallel_realm_gates = multiprocessing.Process(target=gather_system_info)

    # Open the gates and start the mysterious ritual in the background
    parallel_realm_gates.start()

    # Meanwhile, in the earthly realm, print numbers from 1 to 10 (big size) every second
    for i in range(1, 11):
        print(f"Number {i} (big size)")
        time.sleep(1)

    # Obtain the current system date and time
    current_datetime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f"System Date and Time: {current_datetime}")

    # Display the final message
    print("BackGround Record Starts..ALL THE BEST….")
# Out:
# Number 1 (big size)
# Initiating the observation of ethereal processes...
# Spectral PID: 1, Spectral Name: docker-init
# Spectral PID: 8, Spectral Name: node
# Spectral PID: 20, Spectral Name: tail
# Spectral PID: 31, Spectral Name: oom_monitor.sh
# Spectral PID: 33, Spectral Name: run.sh
# Spectral PID: 35, Spectral Name: kernel_manager_proxy
# Spectral PID: 62, Spectral Name: python3
# Spectral PID: 63, Spectral Name: colab-fileshim.
# Spectral PID: 84, Spectral Name: jupyter-noteboo
# Spectral PID: 85, Spectral Name: dap_multiplexer
# Spectral PID: 281, Spectral Name: python3
# Spectral PID: 328, Spectral Name: python3
# Spectral PID: 476, Spectral Name: language_service
# Spectral PID: 481, Spectral Name: node
# Spectral PID: 1253, Spectral Name: python3
# Spectral PID: 1257, Spectral Name: sleep
# Number 2 (big size)
# Number 3 (big size)
# Number 4 (big size)
# Number 5 (big size)
# Number 6 (big size)
# Number 7 (big size)
# Number 8 (big size)
# Number 9 (big size)
# Number 10 (big size)
# System Date and Time: 2023-10-04 08:44:56
# BackGround Record Starts..ALL THE BEST….

# %% [markdown]
# Question 2

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/HousingData.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.shape
# Out:
# (506, 14)

# %%
df.isna().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df['CRIM'].fillna(df['CRIM'].median(),inplace=True)
df['ZN'].fillna(df['ZN'].mean(),inplace=True)
df['INDUS'].fillna(df['INDUS'].mean(),inplace=True)
df['CHAS'].fillna(df['CHAS'].mean(),inplace=True)
df['LSTAT'].fillna(df['LSTAT'].mean(),inplace=True)

# %%
df['AGE'].fillna(df['AGE'].median(),inplace=True)

# %%
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.describe() #summary statistic
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.479140   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.570832   22.921051    6.699165    0.250233    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.083235    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.900000    0.000000    0.538000    6.208500
# 75%      2.808720   11.211934   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.845850    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.486962    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.925000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.575000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.715432   22.532806
# std      7.012739    9.197104
# min      1.730000    5.000000
# 25%      7.230000   17.025000
# 50%     11.995000   21.200000
# 75%     16.570000   25.000000
# max     37.970000   50.000000

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='RM', y='CRIM',hue='MEDV',data=df)
plt.xlabel('RM')
plt.ylabel('Crime rate')
plt.title('Scatter Plot to show median house value based on crime rate and rooms')
plt.show()

# %%
X=df.drop('MEDV',axis=1)
Y=df['MEDV']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
coeffs=model.coef_
features=x_train.columns
feature_importance_df = pd.DataFrame({'Feature': features, 'Coefficient': coeffs})
print(feature_importance_df)
# Out:
#     Feature  Coefficient
# 0      CRIM    -0.125434
# 1        ZN     0.032062
# 2     INDUS    -0.009532
# 3      CHAS     3.679025
# 4       NOX   -13.914535
# 5        RM     4.421932
# 6       AGE    -0.024260
# 7       DIS    -1.419723
# 8       RAD     0.193236
# 9       TAX    -0.007271
# 10  PTRATIO    -0.878665
# 11        B     0.011801
# 12    LSTAT    -0.474600

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='RM', y='MEDV',data=df,alpha=0.5)
plt.xlabel('RM')
plt.ylabel('MEDV')
plt.title('Scatter Plot ')
plt.show()

# %%
from sklearn.metrics import  mean_squared_error

# Make predictions on the test set
y_pred = model.predict(x_test)

# Calculate mse
mse = mean_squared_error(y_test, y_pred)
print(f"Mean squared error {mse:.2f}")
# Out:
# Mean squared error 21.75

# %%
correlation_matrix=df.corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix,cmap='viridis',annot=True,)
plt.show()
